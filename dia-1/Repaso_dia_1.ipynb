# %% [markdown]
# # Día 1 · Repaso — Actividades extra
#
# **Programar para enseñar — Python e IA generativa para Humanidades Digitales**
# Formación docente para EH1023 · Pontificia Universidad Javeriana, Facultad de Ingeniería
#
# ---
#
# Estas **12 actividades** repasan lo del Día 1: pensamiento computacional, fundamentos de Python
# (variables, tipos, operaciones, f-strings, `input()`) y trabajo con **cadenas** (indexación, *slicing*,
# métodos, `len()`, `split()`).
#
# **Cómo usarlas:** lee el enunciado, escribe tu intento en la celda de código y, solo cuando lo hayas
# intentado, abre el recuadro **"Ver solución"** para comparar. No hay una única respuesta correcta:
# lo importante es que tu versión **funcione** y la **entiendas**.
#
# > No necesitas archivos externos: todas las actividades son autocontenidas.

# %% [markdown]
# ## Actividad 1 — Primeras instrucciones
#
# Imprime dos líneas: una que diga `Hola, soy docente de humanidades` y otra con tu materia. Agrega un **comentario** que explique qué hace tu código.

# %%
# Tu solución:

# %% [markdown]
# <details>
# <summary>👀 Ver solución</summary>
#
# ```python
# print("Hola, soy docente de humanidades")
# print("Enseno Literatura")  # segunda linea con la materia
# ```
# </details>

# %% [markdown]
# ## Actividad 2 — Datos de un libro
#
# Crea tres variables: `titulo`, `autor` y `anio` con los datos de un libro que conozcas, y muéstralas en pantalla.

# %%
# Tu solución:

# %% [markdown]
# <details>
# <summary>👀 Ver solución</summary>
#
# ```python
# titulo = "La casa de los espiritus"
# autor = "Isabel Allende"
# anio = 1982
# print(titulo)
# print(autor)
# print(anio)
# ```
# </details>

# %% [markdown]
# ## Actividad 3 — ¿De qué tipo es?
#
# Usa la función `type()` para mostrar el tipo de estos cuatro valores: `"Borges"`, `1944`, `3.5` y `True`.

# %%
# Tu solución:

# %% [markdown]
# <details>
# <summary>👀 Ver solución</summary>
#
# ```python
# print(type("Borges"))
# print(type(1944))
# print(type(3.5))
# print(type(True))
# ```
# </details>

# %% [markdown]
# ## Actividad 4 — Antigüedad de una obra
#
# Una obra se publicó en el año `1605`. Calcula y muestra cuántos años de antigüedad tiene en `2026`, usando una resta.

# %%
# Tu solución:

# %% [markdown]
# <details>
# <summary>👀 Ver solución</summary>
#
# ```python
# anio = 1605
# anio_actual = 2026
# print("Antiguedad:", anio_actual - anio)
# ```
# </details>

# %% [markdown]
# ## Actividad 5 — Referencia con f-string
#
# Con las variables `autor = "Juan Rulfo"`, `anio = 1955` y `titulo = "Pedro Paramo"`, construye y muestra una referencia con el formato: `Juan Rulfo (1955). Pedro Paramo.`

# %%
# Tu solución:

# %% [markdown]
# <details>
# <summary>👀 Ver solución</summary>
#
# ```python
# autor = "Juan Rulfo"
# anio = 1955
# titulo = "Pedro Paramo"
# referencia = f"{autor} ({anio}). {titulo}."
# print(referencia)
# ```
# </details>

# %% [markdown]
# ## Actividad 6 — Edad aproximada (con input)
#
# Pide con `input()` el **año de nacimiento** de una persona, conviértelo a número y muestra su edad aproximada en `2026`. (Recuerda que `input()` devuelve texto.)

# %%
# Tu solución:

# %% [markdown]
# <details>
# <summary>👀 Ver solución</summary>
#
# ```python
# nacimiento = int(input("Anio de nacimiento: "))
# print("Edad aproximada:", 2026 - nacimiento)
# ```
# </details>

# %% [markdown]
# ## Actividad 7 — Primera y última letra
#
# Dada la palabra `palabra = "Quijote"`, imprime su **primera** letra y su **última** letra usando índices.

# %%
# Tu solución:
palabra = "Quijote"

# %% [markdown]
# <details>
# <summary>👀 Ver solución</summary>
#
# ```python
# palabra = "Quijote"
# print(palabra[0])    # primera
# print(palabra[-1])   # ultima
# ```
# </details>

# %% [markdown]
# ## Actividad 8 — Un pedazo del título (slicing)
#
# Del título `titulo = "Cien anios de soledad"`, extrae y muestra solo la palabra `"Cien"` usando *slicing* `[inicio:fin]`.

# %%
# Tu solución:
titulo = "Cien anios de soledad"

# %% [markdown]
# <details>
# <summary>👀 Ver solución</summary>
#
# ```python
# titulo = "Cien anios de soledad"
# print(titulo[0:4])
# ```
# </details>

# %% [markdown]
# ## Actividad 9 — Transformar texto con métodos
#
# Dada la frase `frase = "  La NOVELA del siglo XX  "`, muestra: (a) la frase sin los espacios de los extremos, (b) en minúsculas, y (c) con la palabra `"NOVELA"` reemplazada por `"poesia"`.

# %%
# Tu solución:
frase = "  La NOVELA del siglo XX  "

# %% [markdown]
# <details>
# <summary>👀 Ver solución</summary>
#
# ```python
# frase = "  La NOVELA del siglo XX  "
# print(frase.strip())
# print(frase.lower())
# print(frase.replace("NOVELA", "poesia"))
# ```
# </details>

# %% [markdown]
# ## Actividad 10 — Contar palabras
#
# Dada la oración `oracion = "En un lugar de la Mancha"`, muestra cuántas **palabras** tiene (pista: `split()` + `len()`).

# %%
# Tu solución:
oracion = "En un lugar de la Mancha"

# %% [markdown]
# <details>
# <summary>👀 Ver solución</summary>
#
# ```python
# oracion = "En un lugar de la Mancha"
# print(len(oracion.split()))
# ```
# </details>

# %% [markdown]
# ## Actividad 11 — Caracteres con y sin espacios
#
# Dado `texto = "Humanidades Digitales"`, muestra cuántos caracteres tiene **con** espacios y cuántos **sin** espacios (pista: `replace(" ", "")`).

# %%
# Tu solución:
texto = "Humanidades Digitales"

# %% [markdown]
# <details>
# <summary>👀 Ver solución</summary>
#
# ```python
# texto = "Humanidades Digitales"
# print("Con espacios:", len(texto))
# print("Sin espacios:", len(texto.replace(" ", "")))
# ```
# </details>

# %% [markdown]
# ## Actividad 12 — Reto integrador — mini analizador
#
# Combina lo aprendido (sin usar bucles ni condicionales). Pide un texto con `input()` y muestra: (a) su número de caracteres, (b) su número de palabras, (c) el texto en MAYÚSCULAS, y (d) una vista previa con sus primeros 20 caracteres seguidos de `"..."`.

# %%
# Tu solución:

# %% [markdown]
# <details>
# <summary>👀 Ver solución</summary>
#
# ```python
# texto = input("Escribe un texto: ")
# print("Caracteres:", len(texto))
# print("Palabras:", len(texto.split()))
# print("Mayusculas:", texto.upper())
# print("Vista previa:", texto[0:20] + "...")
# ```
# </details>

# %% [markdown]
# ---
#
# ¡Buen repaso! Si alguna actividad te costó, no te preocupes: vuelve al cuaderno correspondiente del
# Día 1 o pídele al monitor que la repase contigo. Mañana seguimos con **decisiones y repeticiones**.
