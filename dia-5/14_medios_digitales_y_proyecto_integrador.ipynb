# %% [markdown]
# # Día 5 · Cuaderno 14 — Medios digitales y proyecto integrador
#
# **Programar para enseñar — Python e IA generativa para Humanidades Digitales**
# Formación docente para EH1023 · Pontificia Universidad Javeriana, Facultad de Ingeniería
#
# *(Segundo bloque del Día 5 — 2 horas)*
#
# ---
#
# Llegamos al cierre. En esta sesión:
#
# 1. Daremos una mirada a los **medios digitales**: manipular **imágenes** con Python.
# 2. Diseñaremos el **proyecto integrador** del EH1023, donde tus estudiantes reunirán todo.
# 3. Consolidaremos tu **portafolio** y un **mapa** para distribuir el curso en el semestre.

# %% [markdown]
# ## 1. Medios digitales: manipular imágenes con Pillow
#
# Una imagen también son **datos**: una cuadrícula de píxeles, cada uno con color. Con la librería
# **Pillow** (`PIL`) podemos abrir, transformar y guardar imágenes. En Colab ya está instalada; en local:
# `py -m pip install pillow`.
#
# Seguimos el método con IA si quieres, pero aquí el código es corto. Cargamos una imagen de ejemplo del
# repositorio.

# %%
import urllib.request
from PIL import Image

# Descargamos la imagen de ejemplo del repositorio
urllib.request.urlretrieve("https://raw.githubusercontent.com/calderonf/curso-python-humanidades-digitales/main/datos/imagen_ejemplo.png", "imagen.png")

img = Image.open("imagen.png")
print("Tamano (ancho, alto):", img.size)
print("Modo de color:", img.mode)
img

# %% [markdown]
# ### Transformaciones básicas
#
# Tres operaciones muy usadas: **redimensionar**, pasar a **escala de grises** y **rotar**.

# %%
# Redimensionar a la mitad
ancho, alto = img.size
pequena = img.resize((ancho // 2, alto // 2))
print("Nuevo tamano:", pequena.size)
pequena

# %%
# Escala de grises
gris = img.convert("L")   # "L" = luminancia (grises)
gris

# %%
# Rotar 90 grados y guardar el resultado
rotada = img.rotate(90, expand=True)
rotada.save("imagen_rotada.png")
print("Imagen rotada guardada como 'imagen_rotada.png'.")
rotada

# %% [markdown]
# > 🧭 **Nota para docentes.** Las imágenes conectan muy bien con estudios visuales, fotografía y cine.
# > Una actividad sencilla y vistosa: tomar una carpeta de imágenes, redimensionarlas y aplicarles un
# > filtro en lote. El audio y el video se manejan con la misma lógica (con librerías como `pydub` o
# > `moviepy`), pero conviene dejarlos para proyectos más avanzados.

# %% [markdown]
# ## 2. El proyecto integrador del EH1023
#
# Aquí reunimos toda la semana en un **proyecto** que tus estudiantes podrán realizar. La estructura
# recomendada reutiliza el método del curso:
#
# > **Pregunta → Capturar → Procesar → Visualizar → Interpretar**
#
# ### Enunciado base (adáptalo a tu materia)
#
# > *Elige una pregunta de tu área que puedas responder con datos. Captura los datos (de un archivo, una
# > API o una página web), procésalos con Python, crea al menos una visualización y escribe una breve
# > interpretación. Puedes apoyarte en IA (TecGPT, Gemini o Copilot), siempre declarando qué pediste y
# > explicando el código.*
#
# ### Temas sugeridos (según los intereses del grupo)
#
# - **Texto:** frecuencia de palabras o voces de personajes en una obra o corpus.
# - **Datos culturales:** catálogo de obras, playlist o filmografía (por género, por época).
# - **Web/API:** libros de un autor (Open Library), o datos de una página pública.
# - **Medios:** procesamiento de un conjunto de imágenes.
# - **Temas sociales:** palabras clave en titulares o narrativas en prensa/redes.

# %% [markdown]
# ### Entregables del proyecto
#
# 1. **El cuaderno** (`.ipynb`) con el pipeline completo y comentarios.
# 2. **Una visualización** con su interpretación escrita.
# 3. **Una breve reflexión**: ¿qué pediste a la IA?, ¿qué verificaste o corregiste?

# %% [markdown]
# ### Rúbrica de evaluación (lista para usar)
#
# | Criterio | Qué observar | Peso |
# |---|---|---|
# | **Descomposición del problema** | ¿Partió la pregunta en pasos claros (capturar/procesar/visualizar)? | 25% |
# | **Comprensión del código** | ¿Puede explicar qué hace cada parte? | 30% |
# | **Uso crítico de la IA** | ¿Declaró sus prompts y verificó/corrigió el código? | 20% |
# | **Visualización e interpretación** | ¿El gráfico es claro y la interpretación tiene sentido? | 15% |
# | **Funcionamiento** | ¿El pipeline corre y responde la pregunta? | 10% |
#
# Como toda la semana: el **resultado** pesa poco; lo central es **comprender y verificar**.

# %% [markdown]
# ## 3. Mapa para distribuir el EH1023 en el semestre
#
# El EH1023 son **120 horas**. Una forma de distribuir lo que viste esta semana a lo largo del curso:
#
# | Bloque del semestre | Contenido | Apoyado en |
# |---|---|---|
# | Inicio | Pensamiento computacional y fundamentos de Python | Días 1–2 |
# | Intermedio | Datos, archivos y visualización | Día 3 |
# | Intermedio | IA generativa, prompts y uso crítico | Día 4 |
# | Avanzado | APIs, web y medios digitales | Día 5 |
# | Cierre | Proyecto integrador y evaluación | Día 5 |
#
# Los cuadernos de este curso (carpetas `dia-1` a `dia-5`) son tu **material base**: puedes reutilizarlos,
# recortarlos o ampliarlos para tus estudiantes.

# %% [markdown]
# ## 4. Tu portafolio docente
#
# Al terminar la semana deberías tener (en tu Drive o en una copia del repositorio):
#
# - Programas básicos con enfoque humanístico (Días 1–2).
# - Un análisis de datos con visualización (Día 3).
# - Un pipeline con IA y una rúbrica de uso de IA (Día 4).
# - Un ejercicio de API o scraping y uno de medios (Día 5).
# - El **enunciado de tu proyecto integrador** y este **mapa** del semestre.
#
# > Estos materiales son tu punto de partida para impartir el EH1023 con confianza.

# %% [markdown]
# ## 5. Actividad de cierre
#
# 1. Redacta el **enunciado de tu proyecto integrador**, adaptado a tu materia, con su tema, datos y la
#    pregunta que responderá.
# 2. Anota **una política de uso de IA** para ese proyecto (de las que vimos en el Día 4).
# 3. Comparte tu enunciado con un colega y dense retroalimentación: ¿es **alcanzable** para un estudiante
#    que empieza?

# %% [markdown]
# **Plantilla — mi proyecto integrador**
#
# - **Materia / contexto:**
# - **Pregunta a responder:**
# - **Datos y fuente (archivo / API / web):**
# - **Visualización prevista:**
# - **Política de uso de IA:**
# - **¿Por qué es alcanzable para un principiante?**

# %% [markdown]
# ---
#
# ## Cierre del curso
#
# ¡Lo lograste! En cinco días pasaste de **cero** a poder:
#
# - pensar computacionalmente y programar lo esencial en Python;
# - leer y escribir datos, y **visualizarlos**;
# - usar la **IA generativa** de forma crítica y metódica;
# - traer datos de **APIs y la web**, y tocar los **medios digitales**;
# - y, sobre todo, **diseñar actividades** para tus estudiantes con un criterio claro.
#
# Gracias por tu trabajo y tu apertura esta semana. El hilo que nos acompañó —**ustedes delimitan los
# talleres de sus estudiantes, graduando el reto para que cada quien avance con confianza**— es quizá lo
# más valioso que se llevan: tan importante como saber programar es saber **enseñar a programar sin
# desanimar**.
#
# > Guarda y descarga todos tus cuadernos. ¡Mucho éxito impartiendo el EH1023!
